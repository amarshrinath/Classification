# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import recall_score, precision_score, f1_score

# %%
DATA_JOSON_FILE = 'C:/Users/amar/ML Projects/SpamData/01_Processing/email-text-data.json'

# %%
data = pd.read_json(DATA_JOSON_FILE)

# %%
data.head()
# Out:
#    CATEGORY                                            MESSAGE  \
# 0         1  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# 1         1  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# 2         1  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# 3         1  ##############################################...
# 4         1  I thought you might like these:\n\n1) Slim Dow...
#
#                                 FILE_NAME
# 0  00001.7848dde101aa985090474a91ec93fcf0
# 1  00002.d94f1b97e48ed3b553b3508d116e6a09
# 2  00003.2ee33bc6eacdb11f38d052c44819ba6c
# 3  00004.eac8de8d759b7e74154f142194282724
# 4  00005.57696a39d7d84318ce497886896bf90d

# %%
data.tail()
# Out:
#       CATEGORY                                            MESSAGE  \
# 6895         0  Hi Gianni,\n\n\n\nA very good resource for thi...
# 6896         0  Gianni Ponzi wrote:\n\n> I have a prob when tr...
# 6897         0  Neale Pickett <neale@woozle.org> writes:\n\n\n...
# 6898         0  \n\nHi,\n\n\n\nI think you need to give us a l...
# 6899         0
#
#                                    FILE_NAME
# 6895  02497.60497db0a06c2132ec2374b2898084d3
# 6896  02498.09835f512f156da210efb99fcc523e21
# 6897  02499.b4af165650f138b10f9941f6cc5bce3c
# 6898  02500.05b3496ce7bca306bed0805425ec8621
# 6899                                    cmds

# %%
data.shape
# Out:
# (6900, 3)

# %%
vectorizer = CountVectorizer(stop_words='english')  #stopword removing in one line

# %%
all_features = vectorizer.fit_transform(data.MESSAGE)

# %%
all_features.shape
# Out:
# (6900, 92347)

# %%
vectorizer.vocabulary_
# Out:
# {'doctype': 31626,
#  'html': 43690,
#  'public': 66564,
#  'w3c': 84033,
#  'dtd': 33009,
#  'transitional': 79323,
#  'en': 34875,
#  'head': 42398,
#  'meta': 55616,
#  'content': 27527,
#  '3d': 5705,
#  'text': 77892,
#  'charset': 25335,
#  '3dwindows': 6600,
#  '1252': 1755,
#  'http': 43711,
#  'equiv': 35375,
#  '3dcontent': 6219,
#  'ype': 88818,
#  'mshtml': 57046,
#  '00': 0,
#  '2314': 3713,
#  '1000': 1292,
#  '3dgenerator': 6295,
#  'body': 22309,
#  'inserted': 47030,
#  'calypso': 24236,
#  'table': 77136,
#  'border': 22468,
#  '3d0': 5706,
#  'cellpadding': 24955,
#  'cellspacing': 24963,
#  '3d2': 5845,
#  'id': 44970,
#  '3d_calyprintheader_': 6077,
#  'ules': 80851,
#  '3dnone': 6436,
#  'style': 75896,
#  'color': 26745,
#  'black': 21859,
#  'display': 31213,
#  'width': 85580,
#  '100': 1291,
#  'tbody': 77432,
#  'tr': 79199,
#  'td': 77506,
#  'colspan': 26763,
#  '3d3': 5890,
#  'hr': 43603,
#  '3dblack': 6182,
#  'noshade': 59209,
#  'size': 73894,
#  '3d1': 5737,
#  'end': 34936,
#  'font': 38284,
#  '000000': 4,
#  'face': 36728,
#  '3dverdana': 6586,
#  'arial': 18449,
#  'helvetica': 42580,
#  'br': 22682,
#  'ff0000': 37375,
#  'copperplate': 27699,
#  'gothic': 40907,
#  'bold': 22348,
#  '3d5': 5960,
#  'ptsize': 66528,
#  '10': 1290,
#  'center': 24985,
#  'save': 72193,
#  '70': 10106,
#  'life': 52732,
#  'insurance': 47142,
#  'ff': 37371,
#  '0000': 2,
#  'spend': 74916,
#  'pt': 66430,
#  'quote': 68046,
#  'savings': 72206,
#  'align': 17133,
#  '3dleft': 6369,
#  'bordercolor': 22471,
#  '111111': 1567,
#  'wi': 85553,
#  'dth': 33011,
#  '3d650': 6009,
#  '35': 5351,
#  '3d4': 5926,
#  'ensurin': 35102,
#  'family': 36864,
#  'financial': 37705,
#  'security': 72755,
#  'important': 46372,
#  'ma': 54272,
#  'kes': 50389,
#  'buying': 23363,
#  'simple': 73742,
#  'affordable': 16150,
#  'provide': 66242,
#  'free': 38735,
#  'access': 15295,
#  'best': 21160,
#  'companies': 26936,
#  'lowest': 53548,
#  'rates': 68696,
#  '3dmiddle': 6392,
#  'valign': 82451,
#  '3dtop': 6563,
#  '18': 2325,
#  'padding': 62225,
#  'left': 52288,
#  '5px': 8958,
#  'right': 70454,
#  'fast': 36931,
#  'eas': 33837,
#  'saves': 72201,
#  'money': 56555,
#  'let': 52410,
#  'help': 42561,
#  'started': 75389,
#  'val': 82428,
#  'ues': 80528,
#  'country': 27868,
#  'new': 58460,
#  'coverage': 27911,
#  'hundreds': 43806,
#  'tho': 78252,
#  'usands': 81754,
#  'dollars': 31685,
#  'requesting': 69846,
#  'lifequote': 52744,
#  'service': 73043,
#  'minutes': 56063,
#  'complete': 27023,
#  'shop': 73471,
#  'compare': 26952,
#  'types': 80032,
#  'height': 42526,
#  '3d50': 5961,
#  '3dcenter': 6203,
#  'href': 43618,
#  'website': 85206,
#  'e365': 33536,
#  'cc': 24706,
#  'savequote': 72198,
#  'click': 26154,
#  'strong': 75814,
#  'protecting': 66200,
#  'investment': 47443,
#  'll': 53123,
#  'eve': 35815,
#  'make': 54601,
#  'sans': 72096,
#  'serif': 72999,
#  'receipt': 69059,
#  'email': 34688,
#  'error': 35481,
#  'wish': 85754,
#  'removed': 69650,
#  'list': 52931,
#  'mailto': 54507,
#  'coins': 26652,
#  'btamail': 23050,
#  'net': 58368,
#  'cn': 26446,
#  'type': 80025,
#  'remove': 69635,
#  'reside': 69917,
#  'state': 75418,
#  'prohibits': 66057,
#  'mail': 54421,
#  'solicitations': 74550,
#  'insuran': 47141,
#  'ce': 24881,
#  'disregard': 31236,
#  'fight': 37625,
#  'risk': 70518,
#  'cancer': 24289,
#  'www': 86512,
#  'adclick': 15661,
#  'ws': 86295,
#  'cfm': 25095,
#  '315': 5102,
#  'pk007': 64642,
#  'slim': 74117,
#  'guaranteed': 41398,
#  'lose': 53480,
#  '12': 1694,
#  'lbs': 52085,
#  '30': 4986,
#  'days': 29459,
#  '249': 3858,
#  'child': 25484,
#  'support': 76283,
#  'deserve': 30262,
#  'legal': 52302,
#  'advice': 15922,
#  '245': 3843,
#  'pk002': 64641,
#  'join': 49314,
#  'web': 85139,
#  'fastest': 36937,
#  'growing': 41264,
#  'singles': 73796,
#  'community': 26921,
#  '259': 3962,
#  'start': 75387,
#  'private': 65861,
#  'photo': 64204,
#  'album': 17067,
#  'online': 60884,
#  '283': 4155,
#  'wonderful': 86004,
#  'day': 29450,
#  'offer': 60418,
#  'manager': 54673,
#  'prizemama': 65881,
#  'leave': 52255,
#  'use': 81777,
#  'link': 52868,
#  'qves': 68078,
#  'com': 26777,
#  'trim': 79488,
#  'ilug': 46168,
#  'linux': 52896,
#  '7c17': 10634,
#  '7c114258': 10632,
#  'irish': 47720,
#  'users': 81816,
#  'group': 41252,
#  'mailman': 54493,
#  'listinfo': 52967,
#  'subscription': 76001,
#  'information': 46826,
#  'maintainer': 54577,
#  'listmaster': 52972,
#  'zzzz': 91091,
#  'spamassassin': 74768,
#  'taint': 77206,
#  'org': 61237,
#  '7c308417': 10638,
#  'adult': 15872,
#  'club': 26279,
#  'offers': 60428,
#  'membership': 55480,
#  'instant': 47094,
#  'sites': 73855,
#  'user': 81794,
#  'password': 62589,
#  '760382': 10404,
#  'internet': 47270,
#  'news': 58497,
#  '08': 675,
#  '02': 361,
#  'just': 49658,
#  'million': 55962,
#  'members': 55479,
#  'signed': 73675,
#  'month': 56615,
#  '721': 10218,
#  '184': 2357,
#  'faq': 36890,
#  'offering': 60426,
#  'advertisers': 15911,
#  'pay': 62678,
#  'ad': 15585,
#  'space': 74736,
#  'don': 31720,
#  'true': 79581,
#  'absolutely': 15150,
#  'cent': 24981,
#  'account': 15348,
#  'friends': 38878,
#  'yes': 88354,
#  'long': 53407,
#  'age': 16285,
#  'sign': 73661,
#  'following': 38262,
#  'links': 52883,
#  'member': 55477,
#  'multi': 57246,
#  'dollar': 31684,
#  'operations': 61026,
#  'policies': 65097,
#  'rules': 71346,
#  'required': 69849,
#  'info': 46790,
#  'won': 86001,
#  'charge': 25318,
#  'pass': 62559,
#  'believe': 21033,
#  'read': 68926,
#  'terms': 77814,
#  'conditions': 27185,
#  'adults': 15875,
#  'farm': 36905,
#  '80': 11008,
#  '71': 10166,
#  '66': 9426,
#  'aid': 16646,
#  'girls': 40439,
#  'animals': 17708,
#  'getting': 40179,
#  'freaky': 38727,
#  'lifetime': 52749,
#  'sexy': 73138,
#  'celebes': 24925,
#  'celebst': 24939,
#  'thousands': 78278,
#  'xxx': 87715,
#  'doing': 31669,
#  'play': 64773,
#  'house': 43504,
#  'porn': 65209,
#  'mega': 55419,
#  'live': 53009,
#  'feeds': 37259,
#  '60': 9159,
#  'cams': 24273,
#  'asian': 18672,
#  'sex': 73120,
#  'fantasies': 36882,
#  'japanese': 48580,
#  'schoolgirls': 72398,
#  'shows': 73541,
#  'lesbian': 52394,
#  'lace': 51794,
#  'jennifer': 48810,
#  'simpson': 73754,
#  'miami': 55807,
#  'fl': 37915,
#  'entertained': 35124,
#  'boyffriend': 22593,
#  'years': 88311,
#  'joe': 49281,
#  'morgan': 56679,
#  'manhattan': 54704,
#  'ny': 59746,
#  'unbelievable': 81019,
#  'removal': 69629,
#  'instructions': 47118,
#  'received': 69065,
#  'advertisement': 15908,
#  'opted': 61086,
#  'receive': 69064,
#  'specials': 74860,
#  'affiliated': 16130,
#  'websites': 85207,
#  'emails': 34716,
#  'opt': 61082,
#  'database': 29373,
#  'optout': 61129,
#  'allow': 17212,
#  '24': 3817,
#  'hours': 43503,
#  'vonolmosatkirekpups': 83517,
#  'thought': 78272,
#  'like': 52783,
#  'freeyankee': 38820,
#  'cgi': 25178,
#  'fy2': 39336,
#  '822slim1': 11170,
#  '822nic1': 11168,
#  '822ppl1': 11169,
#  'daily': 29244,
#  'deals': 29717,
#  'social': 74467,
#  '7c29': 10635,
#  '7c134077': 10633,
#  'events': 35824,
#  'powerhouse': 65402,
#  'gifting': 40384,
#  'program': 66024,
#  'want': 84381,
#  'miss': 56127,
#  'founders': 38532,
#  'major': 54593,
#  'players': 64778,
#  'invitation': 47454,
#  'experts': 36210,
#  'calling': 24216,
#  'way': 84527,
#  'huge': 43748,
#  'cash': 24530,
#  'flow': 38071,
#  'conceived': 27127,
#  'leverage': 52453,
#  '000': 1,
#  '50': 8132,
#  'question': 67973,
#  'wealthy': 85131,
#  'tossing': 79026,
#  'lifeline': 52741,
#  'sake': 71975,
#  'hope': 43393,
#  'grab': 41032,
#  'hold': 43246,
#  'tight': 78421,
#  'ride': 70430,
#  'testimonials': 77868,
#  'hear': 42458,
#  'average': 19270,
#  'people': 63392,
#  've': 82667,
#  'al': 17007,
#  'single': 73793,
#  'mother': 56744,
#  'sure': 76311,
#  'sent': 72926,
#  'pledge': 64815,
#  'got': 40902,
#  'ky': 51445,
#  'didn': 30827,
#  'partner': 62543,
#  'work': 86055,
#  'think': 78194,
#  'decision': 29798,
#  'pick': 64343,
#  'gave': 39811,
#  'leads': 52224,
#  'training': 79273,
#  'ca': 24081,
#  'announcing': 17774,
#  'close': 26243,
#  'sales': 71989,
#  'fax': 36990,
#  'blast': 21901,
#  'immediately': 46286,
#  'entry': 35173,
#  'wait': 84291,
#  '800': 11009,
#  '421': 7269,
#  '6318': 9289,
#  '896': 11820,
#  '6568': 9399,
#  'name__________________________________phone___________________________________________': 57909,
#  'fax_____________________________________email____________________________________________': 36992,
#  'time': 78460,
#  'call_________________________time': 24208,
#  'zone________________________________________': 90388,
#  'message': 55600,
#  'compliance': 27036,
#  'section': 72732,
#  '301': 4999,
#  'paragraph': 62416,
#  '1618': 2161,
#  'transmissions': 79343,
#  'sender': 72891,
#  'stopped': 75662,
#  'cost': 27805,
#  'sending': 72898,
#  'reply': 69767,
#  'address': 15691,
#  'word': 86042,
#  'subject': 75953,
#  'line': 52842,
#  'errors': 35482,
#  'omissions': 60800,
#  'exceptions': 35995,
#  'excluded': 36023,
#  'spam': 74756,
#  'compiled': 27001,
#  'replicate': 69763,
#  'relative': 69506,
#  'seattle': 72692,
#  'marketing': 54838,
#  'gigt': 40399,
#  'turbo': 79791,
#  'team': 77555,
#  'sole': 74541,
#  'purpose': 66677,
#  'communications': 26911,
#  'continued': 27554,
#  'inclusion': 46524,
#  'gracious': 41041,
#  'permission': 63484,
#  'send': 72885,
#  'tesrewinter': 77851,
#  'yahoo': 88125,
#  'deleted': 30004,
#  'wanted': 84382,
#  '14': 1937,
#  'year': 88304,
#  'old': 60700,
#  'fortune': 38495,
#  '500': 8133,
#  'company': 26939,
#  'tremendous': 79437,
#  'rate': 68693,
#  'looking': 53425,
#  'individuals': 46690,
#  'home': 43280,
#  'opportunity': 61060,
#  'excellent': 35988,
#  'income': 46529,
#  'experience': 36192,
#  'train': 79269,
#  'employed': 34824,
#  'career': 24430,
#  'vast': 82530,
#  'opportunities': 61059,
#  'basetel': 20605,
#  'wealthnow': 85128,
#  'energetic': 34978,
#  'self': 72842,
#  'motivated': 56753,
#  'form': 38429,
#  'employement': 34828,
#  'specialist': 74850,
#  'contact': 27482,
#  '4139volw7': 7231,
#  '758dody1425frhm1': 10382,
#  '764smfc8513fcsll40': 10414,
#  'title': 78552,
#  'reliaquote': 69539,
#  'iso': 47871,
#  '8859': 11781,
#  'leftmargin': 52293,
#  'topmargin': 78987,
#  'ffcc99': 37424,
#  'vlink': 83371,
#  'alink': 17140,
#  'ffcc00': 37421,
#  '468': 7478,
#  'bgcolor': 21315,
#  '993366': 12867,
#  '43': 7312,
#  '56': 8446,
#  'theadmanager': 78074,
#  'server': 73031,
#  'asp': 18707,
#  'ad_key': 15621,
#  'yuesbhwakmlk': 88986,
#  'ext': 36294,
#  'target': 77327,
#  '_blank': 13631,
#  'img': 46247,
#  'src': 75169,
#  'banner': 20495,
#  'bannerads': 20499,
#  'images': 46206,
#  'logo6': 53370,
#  'gif': 40373,
#  '120': 1695,
#  '32': 5132,
#  '44': 7355,
#  'nbsp': 58083,
#  '377': 5478,
#  'ffccff': 37426,
#  'headline6': 42428,
#  '220': 3490,
#  '72': 10212,
#  '336699': 5255,
#  '34': 5290,
#  '45': 7406,
#  'tahoma': 77192,
#  'verdana': 82785,
#  'change': 25266,
#  'protect': 66198,
#  'future': 39201,
#  'sufficient': 76118,
#  'middle': 55882,
#  '27': 4060,
#  'freequotes6': 38788,
#  '177': 2295,
#  '3366cc': 5256,
#  '294': 4235,
#  'freequoteform': 38787,
#  'action': 15519,
#  'termlife': 77810,
#  'bin': 21622,
#  'banner_quote_resp': 20498,
#  'method': 55642,
#  'input': 46988,
#  'hidden': 42834,
#  'value': 82465,
#  '51100004022000000321': 8226,
#  'sourceid': 74688,
#  'class': 26058,
#  'hptbcolor': 43567,
#  'ffffff': 37461,
#  'residence': 69918,
#  '65': 9375,
#  'select': 72824,
#  'formscombobox12': 38458,
#  'option': 61117,
#  'selected': 72830,
#  'alabama': 17028,
#  'alaska': 17045,
#  'arizona': 18465,
#  'arkansas': 18469,
#  'california': 24204,
#  'colorado': 26747,
#  'connecticut': 27325,
#  'delaware': 29993,
#  'dc': 29518,
#  'dist': 31263,
#  'columbia': 26767,
#  'florida': 38064,
#  'georgia': 40108,
#  'hawaii': 42245,
#  'idaho': 45058,
#  'illinois': 46140,
#  'indiana': 46645,
#  'iowa': 47525,
#  'kansas': 50117,
#  'kentucky': 50359,
#  'louisiana': 53515,
#  'maine': 54564,
#  'maryland': 54904,
#  'massachusetts': 54923,
#  'michigan': 55828,
#  'minnesota': 56050,
#  'mississippi': 56140,
#  'missouri': 56142,
#  'montana': 56608,
#  'nebraska': 58234,
#  'nevada': 58455,
#  'hampshire': 42017,
#  'jersey': 48827,
#  'mexico': 55663,
#  'york': 88755,
#  'north': 59180,
#  'carolina': 24473,
#  'dakota': 29254,
#  'ohio': 60543,
#  'oklahoma': 60674,
#  'oregon': 61228,
#  'pennsylvania': 63375,
#  'rhode': 70363,
#  'island': 47853,
#  'south': 74696,
#  'tennessee': 77770,
#  'texas': 77891,
#  'utah': 81884,
#  'vermont': 82813,
#  'virginia': 83180,
#  'washington': 84464,
#  'west': 85322,
#  'wisconsin': 85748,
#  'wyoming': 86594,
#  'date': 29390,
#  'birth': 21677,
#  'mm': 56334,
#  'dd': 29630,
#  'yy': 89287,
#  'nowrap': 59295,
#  '01': 290,
#  '03': 439,
#  '04': 488,
#  '05': 530,
#  '06': 582,
#  '07': 624,
#  '09': 734,
#  '11': 1551,
#  '13': 1828,
#  '15': 2036,
#  '16': 2147,
#  '17': 2241,
#  '19': 2418,
#  '20': 3051,
#  '21': 3410,
#  '22': 3489,
#  '23': 3693,
#  '25': 3892,
#  '26': 3989,
#  '28': 4142,
#  '29': 4217,
#  '31': 5074,
#  '33': 5203,
#  '36': 5395,
#  '37': 5448,
#  '38': 5492,
#  '39': 5526,
#  '40': 7105,
#  '41': 7213,
#  '42': 7265,
#  '46': 7455,
#  '47': 7493,
#  '48': 7539,
#  '49': 7582,
#  '51': 8219,
#  '52': 8271,
#  '53': 8316,
#  '54': 8355,
#  '55': 8398,
#  '57': 8496,
#  '58': 8527,
#  '59': 8565,
#  '61': 9206,
#  '62': 9249,
#  '63': 9285,
#  '64': 9328,
#  '67': 9507,
#  '68': 9541,
#  '69': 9575,
#  '73': 10246,
#  '74': 10291,
#  '75': 10347,
#  '76': 10402,
#  '77': 10437,
#  '78': 10485,
#  '79': 10523,
#  '81': 11096,
#  '82': 11153,
#  '83': 11230,
#  '84': 11318,
#  'formsradiobutton1': 38459,
#  'radio': 68525,
#  'male': 54629,
#  'formsradiobutton2': 38460,
#  'female': 37301,
#  'used': 81781,
#  'tobacco': 78834,
#  'products': 65972,
#  'months': 56623,
#  'formsradiobutton4': 38462,
#  'formsradiobutton3': 38461,
#  'formscombobox11': 38457,
#  '100000': 1294,
#  '125000': 1753,
#  '125': 1751,
#  '150000': 2040,
#  '150': 2037,
#  '175000': 2282,
#  '175': 2280,
#  '200000': 3054,
#  '200': 3052,
#  '225000': 3573,
#  '225': 3570,
#  '250000': 3895,
#  '250': 3893,
#  '275000': 4101,
#  '275': 4099,
#  '300000': 4989,
#  '300': 4987,
#  '325000': 5165,
#  '325': 5163,
#  '350000': 5354,
#  '350': 5352,
#  '375000': 5473,
#  '375': 5472,
#  '400000': 7108,
#  '400': 7106,
#  '425000': 7287,
#  '425': 7286,
#  '450000': 7409,
#  '450': 7407,
#  '475000': 7511,
#  '475': 7510,
#  '500000': 8136,
#  '550000': 8401,
#  '550': 8399,
#  '600000': 9163,
#  '600': 9160,
#  '650000': 9378,
#  '650': 9376,
#  '700000': 10109,
#  '700': 10107,
#  '750000': 10350,
#  '750': 10348,
#  '800000': 11012,
#  '850000': 11420,
#  '850': 11418,
#  '900000': 12493,
#  '900': 12491,
#  '950000': 12683,
#  '950': 12681,
#  '1000000': 1295,
#  '1250000': 1754,
#  '1500000': 2041,
#  '1750000': 2283,
#  '2000000': 3055,
#  '2250000': 3574,
#  '2500000': 3896,
#  '3000000': 4990,
#  '3500000': 5355,
#  '4000000': 7109,
#  '4500000': 7410,
#  '5000000': 8137,
#  '6000000': 9164,
#  '7000000': 10110,
#  '8000000': 11013,
#  '9000000': 12494,
#  '10000000': 1296,
#  '11000000': 1554,
#  '12000000': 1698,
#  '13000000': 1832,
#  '14000000': 1941,
#  '15000000': 2042,
#  'need': 58257,
#  'formscombobox10': 38456,
#  'plan': 64725,
#  'formsbutton1': 38455,
#  'submit': 75975,
#  'submitbutton': 75977,
#  'photo6': 64213,
#  'jpg': 49420,
#  '210': 3411,
#  '173': 2270,
#  '217': 3460,
#  'div': 31327,
#  'makes': 54614,
#  'easy': 33855,
#  'instantly': 47098,
#  'quotes': 68050,
#  'highly': 42861,
#  'rated': 68694,
#  '106': 1477,
#  '70percent6': 10163,
#  '131': 1840,
#  'ffcc33': 37422,
#  'today': 78845,
#  '0000ff': 48,
#  'copyright': 27711,
#  '2001': 3062,
#  'rights': 70465,
#  'reserved': 69908,
#  'admanmail': 15772,
#  'hspace': 43659,
#  'vspace': 83695,
#  'alt': 17278,
#  'receiving': 69072,
#  'mailing': 54483,
#  'sendgreatoffers': 72895,
#  'subscribed': 75995,
#  'jm': 49129,
#  'netnoteinc': 58407,
#  'unsubscribe': 81449,
#  'em': 34661,
#  'sgo': 73218,
#  'include': 46518,
#  'unsubscribed': 81452,
#  'correspondence': 27777,
#  'services': 73045,
#  'directed': 30992,
#  'tired': 78538,
#  'bull': 23208,
#  'stop': 75639,
#  'losing': 53487,
#  'real': 68950,
#  'maker': 54611,
#  'big': 21551,
#  'boys': 22598,
#  'drive': 32891,
#  'doorstep': 31765,
#  'short': 73485,
#  'period': 63445,
#  'print': 65820,
#  'successleads': 76067,
#  'firemail': 37773,
#  'telephone': 77688,
#  'number': 59577,
#  'responding': 69983,
#  '499': 7607,
#  '99': 12850,
#  'name___________________________________': 57902,
#  'phone___________________________________': 64189,
#  'fax_____________________________________': 36991,
#  'email___________________________________': 34697,
#  'dear': 29724,
#  'ricardo1': 70403,
#  'red': 69190,
#  'effective': 34218,
#  'direct': 30989,
#  'advertising': 15913,
#  'blue': 22043,
#  'promote': 66095,
#  'business': 23311,
#  'low': 53539,
#  'addresses': 15707,
#  '44c300': 7394,
#  'maximize': 55027,
#  '309': 5034,
#  '407': 7167,
#  '7378': 10273,
#  'consultant': 27455,
#  'discuss': 31131,
#  'needs': 58266,
#  '___________________________________________________________________': 13565,
#  '_______________________________________________________________': 13561,
#  '________________________________________________________________': 13562,
#  'city': 25847,
#  '_____________________________________________________________________': 13567,
#  'phone': 64185,
#  '__________________________________________________________________': 13564,
#  '_______________________________________________________': 13553,
#  '___________________________________________________________________________': 13571,
#  'comments': 26859,
#  'details': 30344,
#  'pricing': 65789,
#  'market': 54831,
#  '247': 3851,
#  'po1': 65015,
#  'kj': 50719,
#  '_8j7bjk9': 13501,
#  'tg0bk5nkiys5': 77984,
#  'cellular': 24964,
#  'accessories': 15306,
#  'wholesale': 85521,
#  'prices': 65786,
#  '202': 3228,
#  '101': 1336,
#  '163': 2174,
#  'merchant': 55558,
#  'hands': 42046,
#  'ear': 33814,
#  'buds': 23144,
#  'holsters': 43274,
#  '98': 12801,
#  'booster': 22439,
#  'antennas': 17841,
#  'cases': 24528,
#  'car': 24389,
#  'chargers': 25320,
#  'plates': 64757,
#  'lithium': 52992,
#  'ion': 47506,
#  'batteries': 20658,
#  '94': 12651,
#  'nokia': 59086,
#  'motorola': 56770,
#  'lg': 52524,
#  'nextel': 58557,
#  'samsung': 72050,
#  'qualcomm': 67901,
#  'ericsson': 35436,
#  'audiovox': 19077,
#  'phones': 64196,
#  'assistance': 18776,
#  '732': 10253,
#  '751': 10360,
#  '1457': 1984,
#  'mailings': 54486,
#  'request': 69843,
#  'removemenow68994': 69658,
#  'thank': 78051,
#  'super': 76225,
#  'free4pornlovers': 38740,
#  'simply': 73752,
#  'amateur': 17358,
#  '990000': 12853,
#  '660066': 9429,
#  '9933ff': 12868,
#  'girl': 40436,
#  'door': 31761,
#  'tour': 79063,
#  'ff0099': 37380,
#  'photos': 64230,
#  'sneeky': 74374,
#  'nude': 59547,
#  'exibitionists': 36106,
#  'cheating': 25382,
#  'wives': 85783,
#  'girlfriends': 40438,
#  'pl': 64700,
#  'cell': 24945,
#  'spacer': 74739,
#  '185': 2362,
#  'rowspan': 71015,
#  'qbfuiexorxkl': 67215,
#  '168': 2209,
#  '143': 1967,
#  '181': 2340,
#  'htmlemails': 43699,
#  't193no_option_01': 76862,
#  't193no_option_02': 76863,
#  't193no_option_03': 76864,
#  't193no_option_04': 76865,
#  't193no_option_05': 76866,
#  't193no_option_06': 76867,
#  '115': 1603,
#  't193no_option_07': 76868,
#  '154': 2087,
#  't193no_option_08': 76869,
#  't193no_option_09': 76870,
#  't193no_option_10': 76871,
#  't193no_option_11': 76872,
#  't193no_option_12': 76873,
#  't193no_option_13': 76874,
#  't193no_option_14': 76875,
#  '265': 4008,
#  'simplywireless': 73753,
#  'swdotcomlogo1': 76500,
#  '273': 4086,
#  'voicestream': 83482,
#  'wireless': 85736,
#  'credit': 28165,
#  'approval': 18190,
#  'activate': 15527,
#  'activation': 15530,
#  'fee': 37254,
#  'applies': 18147,
#  'activations': 15531,
#  'available': 19251,
#  'areas': 18412,
#  'fulfilled': 39111,
#  'authorized': 19155,
#  'dealer': 29712,
#  'site': 73835,
#  ...}

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, data.CATEGORY, 
                                                   test_size=0.3, random_state=88)

# %%
X_train.shape
# Out:
# (4830, 92347)

# %%
X_test.shape
# Out:
# (2070, 92347)

# %%
classifier = MultinomialNB()

# %%
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# CHALLENGE: Calculate the following for test dataset:
# * num. of doccuments classified correctly
# * num. of doccuments classified incorrectly
# * acuraccy of the model

# %%
nr_correct = (y_test == classifier.predict(X_test)).sum()

# %%
print(f'{nr_correct} documents classified coreectly')
# Out:
# 1963 documents classified coreectly

# %%
nr_incorrect = y_test.size - nr_correct

# %%
print(f'{nr_incorrect} documents classified incoreectly')
# Out:
# 107 documents classified incoreectly

# %%
fraction_wrong = nr_incorrect/ (nr_correct + nr_incorrect)

# %%
print(f'the testing accuracy of the model is :{1-fraction_wrong:.2%}')
# Out:
# the testing accuracy of the model is :94.83%

# %%
classifier.score(X_test, y_test)
# Out:
# 0.9483091787439614

# %% [markdown]
# CHALLEGE: for testing dataset calculate the  (google for scikitlearn doccumentation)
# * recall
# * precision
# * f1 score

# %%
recall_score(y_test, classifier.predict(X_test))
# Out:
# 0.8181818181818182

# %%
precision_score(y_test, classifier.predict(X_test))
# Out:
# 0.9892241379310345

# %%
f1_score(y_test, classifier.predict(X_test))
# Out:
# 0.8956097560975611

# %%
examlple = ['get viagra for free now!', 
           'need a mortage?, Repply to arrange call with a specialist and get a quate',
           'could you please help me with project for tommarrow',
           'hi jonathan how about game of golf tommarow?'
           ]

# %%
doc_term_matrix = vectorizer.transform(examlple)

# %%
classifier.predict(doc_term_matrix)
# Out:
# array([1, 0, 0, 0], dtype=int64)
